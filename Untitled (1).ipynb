# %%
import requests
from bs4 import BeautifulSoup

def scrape_custom_headlines(url):
    """
    Scrape headlines with specific data-testid and class attributes
    
    Args:
        url (str): URL of the news website
        
    Returns:
        list: List of headline dictionaries with text and metadata
    """
    try:
        headers = {
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
        }
        
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        
        # Find all headlines matching your specific structure
        headlines = soup.find_all('h2', {
            'data-testid': 'card-headline',
            'class': lambda x: x and 'sc-9d830f2a-3' in x and 'fWzToZ' in x.split()
        })
        
        results = []
        for headline in headlines:
            results.append({
                'text': headline.get_text(strip=True),
                'class': headline.get('class'),
                'data-testid': headline.get('data-testid')
            })
            
        return results
        
    except requests.exceptions.RequestException as e:
        print(f"Request error: {e}")
        return []
    except Exception as e:
        print(f"Error: {e}")
        return []

# Example usage
if __name__ == "__main__":
    # Replace with the actual URL you're scraping
    target_url = "https://www.bbc.com/news"
    
    headlines = scrape_custom_headlines(target_url)
    
    print(f"Found {len(headlines)} headlines:")
    for idx, headline in enumerate(headlines, 1):
        print(f"{idx}. {headline['text']}")
        print(f"   Class: {headline['class']}")
        print(f"   Test ID: {headline['data-testid']}\n")
# Out:
# Found 38 headlines:
# 1. Thousands protest in Bangkok calling for Thai PM to resign
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 2. Glastonbury Festival 'appalled' by punk duo Bob Vylan's chants about Israeli military
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 3. Serbia police clash with anti-government protesters in Belgrade
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 4. Thousands in Norway told they won up to millions in lottery error
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 5. Thousands protest in Bangkok calling for Thai PM to resign
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 6. Senate Republicans advance Trump's 'Big Beautiful Bill' but final vote hangs in balance
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 7. 'Proud to be gay': K-pop star on coming out to the world
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 8. A pioneering doctor remembers India leader Indira Gandhi's final moments
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 9. Glastonbury Festival 'appalled' by punk duo Bob Vylan's chants about Israeli military
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 10. 'Stop!': Beyoncé pauses show as flying Cadillac tilts mid-air
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 11. The mystery of the paedophile who hired out Disneyland
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 12. At least 81 people killed in Israeli strikes in Gaza, Hamas-run health ministry says
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 13. Rod Stewart brings on Mick Hucknall in star-studded Glastonbury legends slot
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 14. Car bomb attack in Pakistan kills at least 13 soldiers
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 15. A preacher asked me out. When I turned her down, the stalking began
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 16. I feel like I've been gaslit - like the life I had before the war was made up
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 17. Chess club that inspired a Disney film now battling to survive
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 18. A collision challenge is going global - but it's not all fun and games
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 19. A preacher asked me out. When I turned her down, the stalking began
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 20. A pioneering doctor remembers India leader Indira Gandhi's final moments
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 21. Raducanu, Alcaraz, Boulter and heat - Monday's Wimbledon preview
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 22. I feel like I've been gaslit - like the life I had before the war was made up
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 23. Club World Cup: European champions PSG face Messi's Inter Miami in last 16
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 24. Get me to the Euros! How to nab last-minute tickets for a summer of football
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 25. Influencer-turned-boxer Jake Paul dominates Chavez and calls out big names
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 26. 'Proud to be gay': K-pop star on coming out to the world
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 27. Club World Cup: European champions PSG face Messi's Inter Miami in last 16
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 28. Southern Europe swelters as heatwave spreads
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 29. Recap and reaction as Norris wins from Piastri to narrow title gap
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 30. Get me to the Euros! How to nab last-minute tickets for a summer of football
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 31. England denied early opener by Jamaica in final warm-up game
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 32. 'Not football' - Maresca questions Club World Cup hosts after 'joke' delay
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 33. Paul dominates Chavez and calls out big names
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 34. European U21 champions again - but who could make World Cup?
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 35. England denied early opener by Jamaica in final warm-up game
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 36. Norris fights off Piastri for Austria win
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 37. 'Keep the same gag going' - Lowe hits back at stadium announcer
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
#
# 38. 'Not football' - Maresca questions Club World Cup hosts after 'joke' delay
#    Class: ['sc-9d830f2a-3', 'fWzToZ']
#    Test ID: card-headline
